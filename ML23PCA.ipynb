# %%
# PRINCIPLE COMPONENT ANALYSIS(PCA)---> pca is a statical technique that is used to reduse of features diamention in a dataset while keeping as much information/varience
# as possible in short pca transforms your original co-releted features into a new set of un coreleted features called principle components each new feature is a linear
# combination of the original feature it  captures maximum varience in the data it is orthogonal/uncoreleted to the others

# why do we use pca---> to reduce diamentionality (2).to reduce multi colinearlity (3).to visuaize igh diamentional data (4).to reduce noice and improve model generalization
# how pca works---> (1).we will standardize the data (since pca is effected by scales we make all features have mean=0 and std=1) (2).we will compute the covarience matrix and
# the coverience matrrix shows how features vary together (3).now we will computte eigen values and eigan vectors
# eigon vectors --> it represent direction of maximum varience ,eigon values--> it represent the amount of varience captured by each eigon vector (4). now we will sort and select
# top k components --> we will sort eigon vectors by there corosponding eigon values in decending order we will choose the top k eigon vectors that explain most of the varience
# (5).now we will transform the original data--> we project the standardize data on to the new access ,now we have fewer features representing owr original data ex. suppose we have
# a data set of students with features(maths score ,physics score,chemistry score) these subjects are corelated now pca will create new features like (pc1=combination capturing general
# science abbility,pc2-> is the combination capturing unique variation like difference between maths vs otherrs) may be 95% of the datas infoemation is captures in pc1 and pc2
# so you can use those insted of three saprate scores

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
df=pd.read_csv("/content/Social_Network_Ads - Social_Network_Ads.csv")

# %%
df.head(2)
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
df=df.drop(columns=['User ID','Gender'])

# %%
x=df.drop(columns=['Purchased'])
y=df['Purchased']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pipe=Pipeline([('scaler',StandardScaler()),
              ('pca',PCA(n_components=2)),
              ('classifier',RandomForestClassifier(n_estimators=100,random_state=42))])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=2)),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
y_pred=pipe.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8875

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df['fever']=si.fit_transform(df[['fever']])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['gender']=lb.fit_transform(df['gender'])
df['cough']=lb.fit_transform(df['cough'])
df['city']=lb.fit_transform(df['city'])
df['has_covid']=lb.fit_transform(df['has_covid'])

# %%
x=df.drop(columns=['has_covid'])
y=df['has_covid']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pipe=Pipeline([('scaler',StandardScaler()),
              ('pca',PCA(n_components=2)),
              ('classifier',RandomForestClassifier(n_estimators=100,random_state=42))])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=2)),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
y_pred=pipe.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.55

# %%
df=pd.read_csv("/content/insurance - insurance.csv")

# %%
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df['sex']=lb.fit_transform(df['sex'])
df['smoker']=lb.fit_transform(df['smoker'])
df['region']=lb.fit_transform(df['region'])

# %%
# df.isnull().sum()

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pipe=Pipeline([('scaler',StandardScaler()),
              ('pca',PCA(n_components=2)),
              ('Regressor',RandomForestRegressor(n_estimators=100,random_state=42))])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=2)),
#                 ('Regressor', RandomForestRegressor(random_state=42))])

# %%
y_pred=pipe.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.38780246681052677
